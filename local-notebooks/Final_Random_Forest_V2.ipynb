# %%
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# %%
# Loading the datasets
train_df = pd.read_csv('/Users/alitahseen/Desktop/FYP-2024/Machine_learning/Datafiles/Final_Train.csv')
test_df = pd.read_csv('/Users/alitahseen/Desktop/FYP-2024/Machine_learning/Datafiles/Final_test.csv')
validation_df = pd.read_csv('/Users/alitahseen/Desktop/FYP-2024/Machine_learning/Datafiles/Final_Validation.csv')

# %%
# Function to preprocess datasets
def preprocess_data(df):
    df['local_time'] = pd.to_datetime(df['local_time'])
    for time_unit in ['Year', 'Month', 'Day', 'Hour']:
        df[time_unit] = getattr(df['local_time'].dt, time_unit.lower())
    return df.drop('local_time', axis=1)

# %%
# Preprocess all datasets
train_df = preprocess_data(train_df)
test_df = preprocess_data(test_df)
validation_df = preprocess_data(validation_df)

def add_lagged_features(df, n_lags=3):
    for lag in range(1, n_lags + 1):
        df[f'Average_Temp_lag_{lag}'] = df['Average_Temp'].shift(lag)
    return df.dropna().reset_index(drop=True)

train_df = add_lagged_features(train_df)
validation_df = add_lagged_features(validation_df)
test_df = add_lagged_features(test_df)

# %%
# Prepare the feature sets and target variables
def get_features_targets(df):
    feature_cols = ['Year', 'Month', 'Day', 'Hour', 'Average_Temp'] + [f'Average_Temp_lag_{lag}' for lag in range(1, 4)]  # Assuming 3 lags
    X = df[feature_cols]
    y = df['MW']
    return X, y


X_train, y_train = get_features_targets(train_df)
X_validation, y_validation = get_features_targets(validation_df)
X_test, y_test = get_features_targets(test_df)

# %%
def calculate_metrics(actual, predicted, lower_bound=0, upper_bound=100, iqr_multiplier=1.5, epsilon=1e-8):
    # Ignoring negative actual values if considered invalid
    valid_indices = actual > lower_bound
    actual = actual[valid_indices]
    predicted = predicted[valid_indices]

    # Calculate MAE and RMSE
    mae = mean_absolute_error(actual, predicted)
    rmse = np.sqrt(mean_squared_error(actual, predicted))

    # Thresholding for outlier exclusion based on IQR
    q1, q3 = np.percentile(actual, [25, 75])
    iqr = q3 - q1
    outlier_threshold_upper = q3 + (iqr * iqr_multiplier)
    outlier_threshold_lower = q1 - (iqr * iqr_multiplier)

    valid_indices_for_mape = (actual >= outlier_threshold_lower) & (actual <= outlier_threshold_upper)
    filtered_actual = actual[valid_indices_for_mape]
    filtered_predicted = predicted[valid_indices_for_mape]

    # Calculate Modified MAPE with capped at 100%
    if len(filtered_actual) > 0:
        percentage_errors = np.abs((filtered_predicted - filtered_actual) / filtered_actual) * 100
        percentage_errors = np.clip(percentage_errors, None, upper_bound)  # Cap percentage errors at upper_bound (100%)
        mape = np.mean(percentage_errors)
    else:
        mape = np.nan

    # Calculate sMAPE with a small constant epsilon to handle small denominators
    smape = 100/len(actual) * np.sum(2 * np.abs(predicted - actual) / (np.abs(actual) + np.abs(predicted) + epsilon))

    return mae, mape, smape, rmse

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  22.5s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  23.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  22.8s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  20.8s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  12.5s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  12.3s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  12.5s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  33.6s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  34.7s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  34.7s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  11.8s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  12.6s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  32.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  34.7s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  24.9s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  24.3s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  25.1s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  24.8s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  23.3s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  12.6s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  12.3s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  12.5s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  36.4s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  37.4s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  37.4s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  10.7s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  11.5s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  36.5s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  33.8s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  24.5s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  23.7s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  24.5s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  24.1s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  22.7s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  10.6s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  11.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  11.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  36.3s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  10.3s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  11.3s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  35.9s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  37.1s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  33.4s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  36.1s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  23.5s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  22.7s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  23.1s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  22.6s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  20.5s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  10.9s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  11.3s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  11.5s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  34.5s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  33.4s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  10.4s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  11.3s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  34.9s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  31.5s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  34.2s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  22.5s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  21.8s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  20.1s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  22.4s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  22.1s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  11.3s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  10.9s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  11.4s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  33.7s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  32.2s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  33.3s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   9.6s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  10.6s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  32.6s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  29.9s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  22.8s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  22.5s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  23.2s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  21.3s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  23.2s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  11.1s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  10.9s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  11.0s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  34.7s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  33.4s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  35.1s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  10.8s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  10.2s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  31.0s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  33.6s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  22.6s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  22.0s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  22.8s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  20.4s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  22.4s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  33.2s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  14.6s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  14.4s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  15.0s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  32.5s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  33.5s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  29.9s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  32.6s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  13.7s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  14.8s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  30.1s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  28.9s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  30.3s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  29.6s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  27.6s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  12.7s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  13.2s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  12.9s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  44.5s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  43.2s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  44.4s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  11.5s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  12.2s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  40.9s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  43.7s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  25.4s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  24.7s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  25.5s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  23.7s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  25.2s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  11.5s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  11.3s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  11.5s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  38.1s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  10.3s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  11.1s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  36.7s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  38.4s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  37.6s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  34.9s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  23.8s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  23.1s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  23.1s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  24.0s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  21.2s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  12.8s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  12.8s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  13.0s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  35.0s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  33.5s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  34.6s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  30.9s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  11.2s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  11.9s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  33.8s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  24.6s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  23.9s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  24.8s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  22.7s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  24.8s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  11.7s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  11.7s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  12.3s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  36.4s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  37.6s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  38.4s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  12.6s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  11.5s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  36.9s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  34.4s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  24.5s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  23.4s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  24.2s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  24.2s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  21.9s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  11.4s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  11.2s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  11.7s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  36.5s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  10.5s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  11.3s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  35.3s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  36.5s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  33.1s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  36.0s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  22.3s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  21.6s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  22.3s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  20.5s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  23.0s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  10.1s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  10.4s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  10.6s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  33.5s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  32.4s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  10.3s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  11.2s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  33.7s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  30.4s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  33.3s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  23.0s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  21.6s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  22.3s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  19.6s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  21.6s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  11.0s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  10.6s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  11.0s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  32.8s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  31.8s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  32.9s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   9.8s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  10.7s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  32.6s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  29.1s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  21.2s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  20.6s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  21.4s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  20.8s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  19.1s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  10.8s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  10.5s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  10.9s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  32.1s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  32.5s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  34.0s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  11.2s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  12.3s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  32.0s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  35.0s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  24.5s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  23.9s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  20.7s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  24.5s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  22.7s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  30.2s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  27.3s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  27.2s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  21.6s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  24.3s
# Best parameters found by GridSearchCV:
# {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100}

# %%
# Save the model to a file
from joblib import dump
model_filename = '/Users/alitahseen/Desktop/FYP-2024/Machine_learning/notebooks/Trained_Models/best_random_forest_model_V2.joblib'
dump(best_model, model_filename)
# Out:
# ['/Users/alitahseen/Desktop/FYP-2024/Machine_learning/notebooks/Trained_Models/best_random_forest_model_V2.joblib']

# %%
from joblib import load
model_filename = '/Users/alitahseen/Desktop/FYP-2024/Machine_learning/notebooks/Trained_Models/best_random_forest_model_V2.joblib'
loaded_best_model_random_forest = load(model_filename)
y_validation_pred = loaded_best_model_random_forest.predict(X_validation)  # Use X_validation_poly
validation_metrics = calculate_metrics(y_validation, y_validation_pred)
print(f"Validation Metrics: MAE={validation_metrics[0]}, MAPE={validation_metrics[1]}, sMAPE={validation_metrics[2]}, RMSE={validation_metrics[3]}")
# Out:
# Validation Metrics: MAE=50.936533217576255, MAPE=59.75961827528248, sMAPE=61.618469034186674, RMSE=82.81860175548775

# %%
print("Best parameters found by GridSearchCV:")
print(grid_search.best_params_)
# Out:
# Best parameters found by GridSearchCV:
# {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100}
